# %%
import numpy as np
import tensorflow as tf

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(xTrain , yTrain) , (xTest , yTest) = fashion_mnist.load_data()

# %%
xTrain = xTrain/255
yTrain = yTrain/255
xTest = xTest/255 
yTest = yTest/255

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units = 128 , activation = "leaky_relu"),
    tf.keras.layers.Dense(units = 10 , activation = tf.keras.activations.softmax)
])

# %%
model.compile(optimizer = "adam" , loss = tf.keras.losses.sparse_categorical_crossentropy)

# %%
model.fit(xTrain , yTrain , epochs= 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0027
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.1051e-05
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.6472e-06
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 7.7883e-07
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3475e-07

# %%
model.evaluate(xTest , yTest)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 3.4032e-08
# 3.403167525561912e-08
